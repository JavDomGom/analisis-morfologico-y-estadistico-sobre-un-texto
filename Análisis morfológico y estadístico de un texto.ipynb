# %% [markdown]
# ### Extraer palabras del texto

# %%
# palabras = sorted(list(words_set))

# with open('out/palabras_el_quijote.txt', 'a') as f:
#     for palabra in palabras:
#         f.write(f'{palabra}\n')

# %% [markdown]
# ### Generación de DataFrames

# %%
from collections import Counter

import json
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import pandas as pd
import re
import seaborn as sns

# %%
list_of_words = []

with open('in/el_quijote.txt') as file:
    for line in file.readlines():
        line = re.sub(r'[^\w\s]|[\d]', '', line.lower())  # Elimina signos de puntuación.
        list_of_words += line.split()

words_set = set(list_of_words)

# %%
df = pd.DataFrame([{'word': k, 'lenght': len(k), 'count': v} for k, v in Counter(list_of_words).items()])

# %%
with open('out/morfologia.json') as json_file:
    # Convertir el diccionario a un DataFrame.
    dict_df = pd.DataFrame(json.load(json_file))

# Combinar los DataFrames utilizando merge().
df = pd.merge(df, dict_df, left_on='word', right_on='palabra', how='left')

# Eliminar la columna 'palabra' del DataFrame resultante.
df.drop('palabra', axis=1, inplace=True)

df[df['word'].str.startswith('a')]
# Out:
#               word  lenght  count        tipo     genero
# 25       acordarme       9      3       verbo     neutro
# 32       astillero       9      2  sustantivo  masculino
# 33          adarga       6     19  sustantivo   femenino
# 34         antigua       7     17    adjetivo   femenino
# 41            algo       4    127   pronombre     neutro
# ...            ...     ...    ...         ...        ...
# 22582   ahijársele      10      1       verbo     neutro
# 22586      alambre       7      1  sustantivo  masculino
# 22595      atrever       7      1       verbo     neutro
# 22598   advertirás      10      1       verbo     neutro
# 22600  aconsejando      11      1       verbo     neutro
#
# [2825 rows x 5 columns]

# %% [markdown]
# ### Generación de gráficos

# %%
grouped = df.groupby('lenght').size()

ax = grouped.plot(kind='bar')

for y in ax.get_yticks():
    ax.axhline(y, color='gray', linestyle='--', linewidth=0.5)

ax.set_ylim(top=grouped.max()+100)
    
plt.xlabel('Longitud')
plt.ylabel('Palabras')
plt.title('Palabras por longitud')
# Out:
# Text(0.5, 1.0, 'Palabras por longitud')

# %%
top_15 = df.nlargest(10, 'count')

palette = sns.color_palette('summer', len(top_15))

fig, ax = plt.subplots()

bars = ax.barh(top_15['word'], top_15['count'], color=palette)

ax.invert_yaxis()

for x in ax.get_xticks():
    ax.axvline(x, color='gray', linestyle='--', linewidth=0.5)

for bar in bars:
    width = bar.get_width()
    height = bar.get_height()
    ax.text(width, bar.get_y() + height/2, f'{width}', ha='left', va='center')

plt.xlabel('Frecuencia')
plt.ylabel('Palabra')
plt.title('Top 15 palabras más comunes')
# Out:
# Text(0.5, 1.0, 'Top 15 palabras más comunes')

# %%
df_tipo = df.dropna(subset=['tipo'])
count_tipo = df_tipo['tipo'].value_counts()

labels = count_tipo.index
sizes = count_tipo.values

fig, ax = plt.subplots(figsize=(8, 3.8))
_, _, autotexts = ax.pie(sizes, labels=None, autopct='%1.1f%%', startangle=300, wedgeprops=dict(width=0.2), textprops={'fontsize': 10}, radius=0.5)
ax.axis('equal')
plt.title('Tipos de palabras')

legend_labels = [f'{label} ({size} - {percent:.1f}%)' for label, size, percent in zip(labels, sizes, sizes/sum(sizes)*100)]
plt.legend(legend_labels, loc='upper right', title='Detalle', fontsize='small')

for autotext in autotexts:
    autotext.set_visible(False)  # Oculta los valores de "word" en los segmentos del anillo.

plt.tight_layout()

# %%
df_genero = df.dropna(subset=['genero'])
grouped = df_genero['genero'].value_counts().sort_values(ascending=False)

plt.bar(grouped.index, grouped.values)

ax = plt.gca()
yticks = ax.get_yticks()
for ytick in yticks:
    plt.axhline(y=ytick, color='gray', linestyle='--', linewidth=0.5)

plt.xticks()
plt.xlabel('Género')
plt.ylabel('Cantidad')
plt.title('Distribución por género')
# Out:
# Text(0.5, 1.0, 'Distribución por género')

# %%
# Crear la figura y la matriz de subgráficos.
fig, axes = plt.subplots(2, 2, figsize=(16, 9))

# Gráfico 1 - Palabras por longitud.
grouped = df.groupby('lenght').size()
ax1 = axes[0, 0]
grouped.plot(kind='bar', ax=ax1)

for y in ax1.get_yticks():
    ax1.axhline(y, color='gray', linestyle='--', linewidth=0.5)

ax1.set_ylim(top=grouped.max()+100)
ax1.set_xlabel('Longitud')
ax1.set_ylabel('Palabras')
ax1.set_title('Palabras por longitud')

# Gráfico 2 - Top 15 palabras.
top_15 = df.nlargest(15, 'count')
palette = sns.color_palette('summer', len(top_15))
ax2 = axes[0, 1]
bars = ax2.barh(top_15['word'], top_15['count'], color=palette)

ax2.invert_yaxis()

for x in ax2.get_xticks():
    ax2.axvline(x, color='gray', linestyle='--', linewidth=0.5)

for bar in bars:
    width = bar.get_width()
    height = bar.get_height()
    ax2.text(width, bar.get_y() + height/2, f'{width}', ha='left', va='center')

ax2.set_xlabel('Cantidad')
ax2.set_ylabel('Palabra')
ax2.set_title('Top 15 palabras más comunes')

# Gráfico 3 - Tipos de palabras.
df_tipo = df.dropna(subset=['tipo'])
count_tipo = df_tipo['tipo'].value_counts()

labels = count_tipo.index
sizes = count_tipo.values

ax3 = axes[1, 0]
_, _, autotexts = ax3.pie(
    sizes, labels=None, autopct='%1.1f%%', startangle=300,
    wedgeprops=dict(width=0.21), textprops={'fontsize': 10}, radius=0.5
)
ax3.axis('equal')
ax3.set_title('Tipos de palabras')

legend_labels = [f'{label} ({size} - {percent:.1f}%)' for label, size, percent in zip(labels, sizes, sizes/sum(sizes)*100)]
ax3.legend(legend_labels, loc='upper right', title='Proporción', fontsize='small')

for autotext in autotexts:
    autotext.set_visible(False)  # Oculta los valores de "word" en los segmentos del anillo.

# Ajustar los límites del eje X para dejar espacio a la izquierda.
ax3.set_xlim(left=-0.001)

# Gráfico 4 - Distribución por género.
df_genero = df.dropna(subset=['genero'])
grouped = df_genero['genero'].value_counts().sort_values(ascending=False)

ax4 = axes[1, 1]

sns.barplot(x=grouped.index, y=grouped.values, palette='BuGn', ax=ax4)

ax = plt.gca()
yticks = ax.get_yticks()
for ytick in yticks:
    ax4.axhline(y=ytick, color='gray', linestyle='--', linewidth=0.5)
    
ax4.set_xlabel('Género')
ax4.set_ylabel('Cantidad')
ax4.set_title('Distribución por género')

# Ajustar el espaciado entre subgráficos.
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %%
df['primera letra'] = df['word'].str[0]
letter_counts = df.groupby('primera letra').size()

plt.figure(figsize=(14, 5))
plt.bar(letter_counts.index, letter_counts.values)
plt.xlabel('Primera letra')
plt.ylabel('Palabras')

plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)

# Agregar los valores en la parte superior de las barras.
for i, value in enumerate(letter_counts.values):
    plt.text(i, value, str(value), ha='center', va='bottom', size=8)

# %% [markdown]
# ### Frecuencia por primera letra en tipos de palabras

# %%
# Tipos de palabras que queremos filtrar.
tipos_filtrados = ['verbo', 'sustantivo', 'adjetivo', 'adverbio', 'nombre propio', 'pronombre']

# Filtrar el DataFrame original por los tipos de palabras seleccionados.
df_filtrado = df[df['tipo'].isin(tipos_filtrados)]

# Obtener los tipos de palabras únicos del DataFrame filtrado.
tipos_palabras = df_filtrado['tipo'].unique()

# Crear una malla de subgráficos de 2x3
fig, axs = plt.subplots(2, 3, figsize=(13, 6))

# Iterar sobre los tipos de palabras y crear un gráfico para cada uno.
for i, tipo in enumerate(tipos_palabras):
    # Filtrar el DataFrame filtrado por el tipo de palabra actual.
    df_tipo = df_filtrado[df_filtrado['tipo'] == tipo]
    
    # Calcular el recuento de sustantivos por cada primera letra.
    recuento_letras = df_tipo['primera letra'].value_counts()
    
    # Ordenar las letras en orden alfabético.
    recuento_letras = recuento_letras.sort_index()
    
    # Obtener todas las letras únicas
    todas_letras = sorted(df['primera letra'].unique())
    
    # Crear una nueva Serie con todas las letras y establecer los valores en 0.
    recuento_letras_completo = pd.Series(0, index=todas_letras)
    
    # Combinar los recuentos de las letras existentes con el conjunto completo.
    recuento_letras_completo.update(recuento_letras)
    
    # Obtener los índices de fila y columna en la malla de subgráficos.
    row = i // 3
    col = i % 3
    
    # Seleccionar el subgráfico correspondiente en la malla.
    ax = axs[row, col]
    
    # Dibujar líneas grises horizontales en cada ytick.
    ax.yaxis.grid(color='gray', linestyle='--', linewidth=0.5)
    
    # Crear el gráfico de líneas en el subgráfico actual.
    ax.plot(recuento_letras_completo.index, recuento_letras_completo.values, drawstyle='steps-mid', color='green')
    
    # Configurar las etiquetas de los ejes y el título.
    ax.set_xlabel('Primera letra')
    ax.set_ylabel('Frecuencia')
    ax.set_title(tipo)

# Ajustar el espaciado entre los subplots y mostrar el gráfico.
plt.tight_layout()

# %%
# Crear una figura y un eje para el gráfico.
fig, ax = plt.subplots(figsize=(15, 5))

# Iterar sobre los tipos de palabras y crear una línea para cada uno.
for i, tipo in enumerate(tipos_filtrados):
    # Filtrar el DataFrame filtrado por el tipo de palabra actual.
    df_tipo = df_filtrado[df_filtrado['tipo'] == tipo]
    
    recuento_letras = df_tipo['primera letra'].value_counts()
    
    # Ordenar las letras en orden alfabético.
    recuento_letras = recuento_letras.sort_index()
    
    # Obtener todas las letras sin repetir.
    todas_letras = sorted(df['primera letra'].unique())
    
    # Crear una nueva Serie con todas las letras y establecer los valores en 0.
    recuento_letras_completo = pd.Series(0, index=todas_letras)
    
    # Combinar los recuentos de las letras existentes con el conjunto completo.
    recuento_letras_completo.update(recuento_letras)
    
    # Crear el gráfico de líneas con líneas curvas y color asignado.
    ax.plot(recuento_letras_completo.index, recuento_letras_completo.values, label=tipo)

# Dibujar líneas grises horizontales en cada ytick.
ax.yaxis.grid(color='gray', linestyle='--', linewidth=0.5)

# Dibujar líneas grises verticales en cada xtick.
ax.xaxis.grid(color='gray', linestyle='--', linewidth=0.5)

# Establecer la frecuencia de los yticks.
ax.yaxis.set_major_locator(ticker.MultipleLocator(100))

# Configurar las etiquetas de los ejes y el título.
ax.set_xlabel('Primera letra')
ax.set_ylabel('Frecuencia')
ax.set_title('Frecuencia en tipos de palabras por su primera letra')

# Mostrar la leyenda con los tipos de palabras.
ax.legend();

# %% [markdown]
# ### Frecuencia de palabras adyacentes 2-gram

# %%
import nltk
# nltk.download('punkt')
from nltk import ngrams
from collections import defaultdict

# %%
# Creación de los bigramas en base al texto sin signos de puntuación ni espacios.
bigrams = list(ngrams(list_of_words, 2))

# %%
# Diccionario para almacenar las estadísticas de palabras siguientes.
siguientes_palabras = defaultdict(list)

# Obtener las palabras siguientes para cada bigrama con "que" como primer elemento.
for bigram in bigrams:
    if bigram[0].lower() in [w for w in top_15['word']]:
        siguientes_palabras[bigram[0]].append(bigram[1])

# Convertir el defaultdict en un diccionario estándar.
siguientes_palabras = dict(siguientes_palabras)

# %%
data_set = []

for word, next_words in Counter(siguientes_palabras).items():
    for next_word, count in Counter(next_words).items():
        data_set.append({'word': word, 'next_word': next_word, 'lenght': len(next_word), 'count': count})
        
df_2_gram = pd.DataFrame(data_set)

# %%
df_grouped = df_2_gram.groupby('word')
dataframes = []

# Iterar sobre los grupos y crear DataFrames separados.
for group_name, group_df in df_grouped:
    
    # Ordenar los valores de la columna "count" en orden descendente.
    group_df_sorted = group_df.sort_values(by='count', ascending=False)
    
    # Quedarse solo con los 10 primeros valores.
    group_df_top10 = group_df_sorted.head(10)
    
    dataframes.append(group_df_top10)

# %% [markdown]
# ### Top 10 de palabras siguientes por cada palabra más repetida en el texto

# %%
# Cuadrícula de subplots de 5x3.
fig, axs = plt.subplots(5, 3, figsize=(12.5, 16))

# Paleta de colores.
colors = sns.color_palette('flare', 10)[::-1]

# Coordenadas personalizadas para los subplots.
coord = [(0, 0), (0, 1), (0, 2),
         (1, 0), (1, 1), (1, 2),
         (2, 0), (2, 1), (2, 2),
         (3, 0), (3, 1), (3, 2),
         (4, 0), (4, 1), (4, 2)]

# Iterar sobre los DataFrames y dibujar los gráficos de barras en los subplots.
for i, df in enumerate(dataframes):
    # Obtener las coordenadas correspondientes al DataFrame actual.
    row, col = coord[i]
    
    # Seleccionar el subplot correspondiente.
    ax = axs[row, col]
    
    # Ordenar los valores de la columna "count" en orden descendente.
    df_sorted = df.sort_values(by='count', ascending=False)
    
    # Quedarse solo con los 10 primeros valores.
    df_top10 = df_sorted.head(10)
    
    # Inclinar los xticks en 90 grados.
    xticks = range(len(df_top10['next_word']))
    ax.set_xticks(xticks)
    ax.set_xticklabels(df_top10['next_word'], rotation=90)
    
    # Establecer el límite del eje "y".
    max_count = df['count'].max()
    ax.set_ylim(0, df_2_gram['count'].max() + 250)
    
    # Dibujar líneas grises horizontales en cada ytick.
    ax.yaxis.grid(color='gray', linestyle='--', linewidth=0.5)
    
    # Configurar el gráfico de barras en el subplot.
    sns.barplot(x='next_word', y='count', data=df_top10, ax=ax, palette=colors, saturation=1)

    # Agregar los valores en la cima de cada barra.
    for x, y in zip(range(len(df['next_word'])), df['count']):
        ax.annotate(
            str(y), xy=(x, y), xytext=(0, 3), textcoords='offset points',
            ha='center', va='bottom', size=8
        )
    
    # Establecer etiquetas en los ejes "x" e "y".
    ax.set_xlabel('Top 10 siguientes palabras', fontsize=10)
    ax.set_ylabel('Frecuencia', fontsize=10)
    
    # Título de cada gráfico.
    ax.set_title(f"#{df['word'].iloc[0]}")

# Ajustar el espaciado entre los subplots y mostrar el gráfico.
plt.tight_layout()

# %%
bigrams
# Out:
# [('primera', 'parte'),
#  ('parte', 'del'),
#  ('del', 'ingenioso'),
#  ('ingenioso', 'hidalgo'),
#  ('hidalgo', 'don'),
#  ('don', 'quijote'),
#  ('quijote', 'de'),
#  ('de', 'la'),
#  ('la', 'mancha'),
#  ('mancha', 'capítulo'),
#  ('capítulo', 'primero'),
#  ('primero', 'que'),
#  ('que', 'trata'),
#  ('trata', 'de'),
#  ('de', 'la'),
#  ('la', 'condición'),
#  ('condición', 'y'),
#  ('y', 'ejercicio'),
#  ('ejercicio', 'del'),
#  ('del', 'famoso'),
#  ('famoso', 'hidalgo'),
#  ('hidalgo', 'don'),
#  ('don', 'quijote'),
#  ('quijote', 'de'),
#  ('de', 'la'),
#  ('la', 'mancha'),
#  ('mancha', 'en'),
#  ('en', 'un'),
#  ('un', 'lugar'),
#  ('lugar', 'de'),
#  ('de', 'la'),
#  ('la', 'mancha'),
#  ('mancha', 'de'),
#  ('de', 'cuyo'),
#  ('cuyo', 'nombre'),
#  ('nombre', 'no'),
#  ('no', 'quiero'),
#  ('quiero', 'acordarme'),
#  ('acordarme', 'no'),
#  ('no', 'ha'),
#  ('ha', 'mucho'),
#  ('mucho', 'tiempo'),
#  ('tiempo', 'que'),
#  ('que', 'vivía'),
#  ('vivía', 'un'),
#  ('un', 'hidalgo'),
#  ('hidalgo', 'de'),
#  ('de', 'los'),
#  ('los', 'de'),
#  ('de', 'lanza'),
#  ('lanza', 'en'),
#  ('en', 'astillero'),
#  ('astillero', 'adarga'),
#  ('adarga', 'antigua'),
#  ('antigua', 'rocín'),
#  ('rocín', 'flaco'),
#  ('flaco', 'y'),
#  ('y', 'galgo'),
#  ('galgo', 'corredor'),
#  ('corredor', 'una'),
#  ('una', 'olla'),
#  ('olla', 'de'),
#  ('de', 'algo'),
#  ('algo', 'más'),
#  ('más', 'vaca'),
#  ('vaca', 'que'),
#  ('que', 'carnero'),
#  ('carnero', 'salpicón'),
#  ('salpicón', 'las'),
#  ('las', 'más'),
#  ('más', 'noches'),
#  ('noches', 'duelos'),
#  ('duelos', 'y'),
#  ('y', 'quebrantos'),
#  ('quebrantos', 'los'),
#  ('los', 'sábados'),
#  ('sábados', 'lantejas'),
#  ('lantejas', 'los'),
#  ('los', 'viernes'),
#  ('viernes', 'algún'),
#  ('algún', 'palomino'),
#  ('palomino', 'de'),
#  ('de', 'añadidura'),
#  ('añadidura', 'los'),
#  ('los', 'domingos'),
#  ('domingos', 'consumían'),
#  ('consumían', 'las'),
#  ('las', 'tres'),
#  ('tres', 'partes'),
#  ('partes', 'de'),
#  ('de', 'su'),
#  ('su', 'hacienda'),
#  ('hacienda', 'el'),
#  ('el', 'resto'),
#  ('resto', 'della'),
#  ('della', 'concluían'),
#  ('concluían', 'sayo'),
#  ('sayo', 'de'),
#  ('de', 'velarte'),
#  ('velarte', 'calzas'),
#  ('calzas', 'de'),
#  ('de', 'velludo'),
#  ('velludo', 'para'),
#  ('para', 'las'),
#  ('las', 'fiestas'),
#  ('fiestas', 'con'),
#  ('con', 'sus'),
#  ('sus', 'pantuflos'),
#  ('pantuflos', 'de'),
#  ('de', 'lo'),
#  ('lo', 'mesmo'),
#  ('mesmo', 'y'),
#  ('y', 'los'),
#  ('los', 'días'),
#  ('días', 'de'),
#  ('de', 'entresemana'),
#  ('entresemana', 'se'),
#  ('se', 'honraba'),
#  ('honraba', 'con'),
#  ('con', 'su'),
#  ('su', 'vellorí'),
#  ('vellorí', 'de'),
#  ('de', 'lo'),
#  ('lo', 'más'),
#  ('más', 'fino'),
#  ('fino', 'tenía'),
#  ('tenía', 'en'),
#  ('en', 'su'),
#  ('su', 'casa'),
#  ('casa', 'una'),
#  ('una', 'ama'),
#  ('ama', 'que'),
#  ('que', 'pasaba'),
#  ('pasaba', 'de'),
#  ('de', 'los'),
#  ('los', 'cuarenta'),
#  ('cuarenta', 'y'),
#  ('y', 'una'),
#  ('una', 'sobrina'),
#  ('sobrina', 'que'),
#  ('que', 'no'),
#  ('no', 'llegaba'),
#  ('llegaba', 'a'),
#  ('a', 'los'),
#  ('los', 'veinte'),
#  ('veinte', 'y'),
#  ('y', 'un'),
#  ('un', 'mozo'),
#  ('mozo', 'de'),
#  ('de', 'campo'),
#  ('campo', 'y'),
#  ('y', 'plaza'),
#  ('plaza', 'que'),
#  ('que', 'así'),
#  ('así', 'ensillaba'),
#  ('ensillaba', 'el'),
#  ('el', 'rocín'),
#  ('rocín', 'como'),
#  ('como', 'tomaba'),
#  ('tomaba', 'la'),
#  ('la', 'podadera'),
#  ('podadera', 'frisaba'),
#  ('frisaba', 'la'),
#  ('la', 'edad'),
#  ('edad', 'de'),
#  ('de', 'nuestro'),
#  ('nuestro', 'hidalgo'),
#  ('hidalgo', 'con'),
#  ('con', 'los'),
#  ('los', 'cincuenta'),
#  ('cincuenta', 'años'),
#  ('años', 'era'),
#  ('era', 'de'),
#  ('de', 'complexión'),
#  ('complexión', 'recia'),
#  ('recia', 'seco'),
#  ('seco', 'de'),
#  ('de', 'carnes'),
#  ('carnes', 'enjuto'),
#  ('enjuto', 'de'),
#  ('de', 'rostro'),
#  ('rostro', 'gran'),
#  ('gran', 'madrugador'),
#  ('madrugador', 'y'),
#  ('y', 'amigo'),
#  ('amigo', 'de'),
#  ('de', 'la'),
#  ('la', 'caza'),
#  ('caza', 'quieren'),
#  ('quieren', 'decir'),
#  ('decir', 'que'),
#  ('que', 'tenía'),
#  ('tenía', 'el'),
#  ('el', 'sobrenombre'),
#  ('sobrenombre', 'de'),
#  ('de', 'quijada'),
#  ('quijada', 'o'),
#  ('o', 'quesada'),
#  ('quesada', 'que'),
#  ('que', 'en'),
#  ('en', 'esto'),
#  ('esto', 'hay'),
#  ('hay', 'alguna'),
#  ('alguna', 'diferencia'),
#  ('diferencia', 'en'),
#  ('en', 'los'),
#  ('los', 'autores'),
#  ('autores', 'que'),
#  ('que', 'deste'),
#  ('deste', 'caso'),
#  ('caso', 'escriben'),
#  ('escriben', 'aunque'),
#  ('aunque', 'por'),
#  ('por', 'conjeturas'),
#  ('conjeturas', 'verosímiles'),
#  ('verosímiles', 'se'),
#  ('se', 'deja'),
#  ('deja', 'entender'),
#  ('entender', 'que'),
#  ('que', 'se'),
#  ('se', 'llamaba'),
#  ('llamaba', 'quejana'),
#  ('quejana', 'pero'),
#  ('pero', 'esto'),
#  ('esto', 'importa'),
#  ('importa', 'poco'),
#  ('poco', 'a'),
#  ('a', 'nuestro'),
#  ('nuestro', 'cuento'),
#  ('cuento', 'basta'),
#  ('basta', 'que'),
#  ('que', 'en'),
#  ('en', 'la'),
#  ('la', 'narración'),
#  ('narración', 'dél'),
#  ('dél', 'no'),
#  ('no', 'se'),
#  ('se', 'salga'),
#  ('salga', 'un'),
#  ('un', 'punto'),
#  ('punto', 'de'),
#  ('de', 'la'),
#  ('la', 'verdad'),
#  ('verdad', 'es'),
#  ('es', 'pues'),
#  ('pues', 'de'),
#  ('de', 'saber'),
#  ('saber', 'que'),
#  ('que', 'este'),
#  ('este', 'sobredicho'),
#  ('sobredicho', 'hidalgo'),
#  ('hidalgo', 'los'),
#  ('los', 'ratos'),
#  ('ratos', 'que'),
#  ('que', 'estaba'),
#  ('estaba', 'ocioso'),
#  ('ocioso', 'que'),
#  ('que', 'eran'),
#  ('eran', 'los'),
#  ('los', 'más'),
#  ('más', 'del'),
#  ('del', 'año'),
#  ('año', 'se'),
#  ('se', 'daba'),
#  ('daba', 'a'),
#  ('a', 'leer'),
#  ('leer', 'libros'),
#  ('libros', 'de'),
#  ('de', 'caballerías'),
#  ('caballerías', 'con'),
#  ('con', 'tanta'),
#  ('tanta', 'afición'),
#  ('afición', 'y'),
#  ('y', 'gusto'),
#  ('gusto', 'que'),
#  ('que', 'olvidó'),
#  ('olvidó', 'casi'),
#  ('casi', 'de'),
#  ('de', 'todo'),
#  ('todo', 'punto'),
#  ('punto', 'el'),
#  ('el', 'ejercicio'),
#  ('ejercicio', 'de'),
#  ('de', 'la'),
#  ('la', 'caza'),
#  ('caza', 'y'),
#  ('y', 'aun'),
#  ('aun', 'la'),
#  ('la', 'administración'),
#  ('administración', 'de'),
#  ('de', 'su'),
#  ('su', 'hacienda'),
#  ('hacienda', 'y'),
#  ('y', 'llegó'),
#  ('llegó', 'a'),
#  ('a', 'tanto'),
#  ('tanto', 'su'),
#  ('su', 'curiosidad'),
#  ('curiosidad', 'y'),
#  ('y', 'desatino'),
#  ('desatino', 'en'),
#  ('en', 'esto'),
#  ('esto', 'que'),
#  ('que', 'vendió'),
#  ('vendió', 'muchas'),
#  ('muchas', 'hanegas'),
#  ('hanegas', 'de'),
#  ('de', 'tierra'),
#  ('tierra', 'de'),
#  ('de', 'sembradura'),
#  ('sembradura', 'para'),
#  ('para', 'comprar'),
#  ('comprar', 'libros'),
#  ('libros', 'de'),
#  ('de', 'caballerías'),
#  ('caballerías', 'en'),
#  ('en', 'que'),
#  ('que', 'leer'),
#  ('leer', 'y'),
#  ('y', 'así'),
#  ('así', 'llevó'),
#  ('llevó', 'a'),
#  ('a', 'su'),
#  ('su', 'casa'),
#  ('casa', 'todos'),
#  ('todos', 'cuantos'),
#  ('cuantos', 'pudo'),
#  ('pudo', 'haber'),
#  ('haber', 'dellos'),
#  ('dellos', 'y'),
#  ('y', 'de'),
#  ('de', 'todos'),
#  ('todos', 'ningunos'),
#  ('ningunos', 'le'),
#  ('le', 'parecían'),
#  ('parecían', 'tan'),
#  ('tan', 'bien'),
#  ('bien', 'como'),
#  ('como', 'los'),
#  ('los', 'que'),
#  ('que', 'compuso'),
#  ('compuso', 'el'),
#  ('el', 'famoso'),
#  ('famoso', 'feliciano'),
#  ('feliciano', 'de'),
#  ('de', 'silva'),
#  ('silva', 'porque'),
#  ('porque', 'la'),
#  ('la', 'claridad'),
#  ('claridad', 'de'),
#  ('de', 'su'),
#  ('su', 'prosa'),
#  ('prosa', 'y'),
#  ('y', 'aquellas'),
#  ('aquellas', 'entricadas'),
#  ('entricadas', 'razones'),
#  ('razones', 'suyas'),
#  ('suyas', 'le'),
#  ('le', 'parecían'),
#  ('parecían', 'de'),
#  ('de', 'perlas'),
#  ('perlas', 'y'),
#  ('y', 'más'),
#  ('más', 'cuando'),
#  ('cuando', 'llegaba'),
#  ('llegaba', 'a'),
#  ('a', 'leer'),
#  ('leer', 'aquellos'),
#  ('aquellos', 'requiebros'),
#  ('requiebros', 'y'),
#  ('y', 'cartas'),
#  ('cartas', 'de'),
#  ('de', 'desafíos'),
#  ('desafíos', 'donde'),
#  ('donde', 'en'),
#  ('en', 'muchas'),
#  ('muchas', 'partes'),
#  ('partes', 'hallaba'),
#  ('hallaba', 'escrito'),
#  ('escrito', 'la'),
#  ('la', 'razón'),
#  ('razón', 'de'),
#  ('de', 'la'),
#  ('la', 'sinrazón'),
#  ('sinrazón', 'que'),
#  ('que', 'a'),
#  ('a', 'mi'),
#  ('mi', 'razón'),
#  ('razón', 'se'),
#  ('se', 'hace'),
#  ('hace', 'de'),
#  ('de', 'tal'),
#  ('tal', 'manera'),
#  ('manera', 'mi'),
#  ('mi', 'razón'),
#  ('razón', 'enflaquece'),
#  ('enflaquece', 'que'),
#  ('que', 'con'),
#  ('con', 'razón'),
#  ('razón', 'me'),
#  ('me', 'quejo'),
#  ('quejo', 'de'),
#  ('de', 'la'),
#  ('la', 'vuestra'),
#  ('vuestra', 'fermosura'),
#  ('fermosura', 'y'),
#  ('y', 'también'),
#  ('también', 'cuando'),
#  ('cuando', 'leía'),
#  ('leía', 'los'),
#  ('los', 'altos'),
#  ('altos', 'cielos'),
#  ('cielos', 'que'),
#  ('que', 'de'),
#  ('de', 'vuestra'),
#  ('vuestra', 'divinidad'),
#  ('divinidad', 'divinamente'),
#  ('divinamente', 'con'),
#  ('con', 'las'),
#  ('las', 'estrellas'),
#  ('estrellas', 'os'),
#  ('os', 'fortifican'),
#  ('fortifican', 'y'),
#  ('y', 'os'),
#  ('os', 'hacen'),
#  ('hacen', 'merecedora'),
#  ('merecedora', 'del'),
#  ('del', 'merecimiento'),
#  ('merecimiento', 'que'),
#  ('que', 'merece'),
#  ('merece', 'la'),
#  ('la', 'vuestra'),
#  ('vuestra', 'grandeza'),
#  ('grandeza', 'con'),
#  ('con', 'estas'),
#  ('estas', 'razones'),
#  ('razones', 'perdía'),
#  ('perdía', 'el'),
#  ('el', 'pobre'),
#  ('pobre', 'caballero'),
#  ('caballero', 'el'),
#  ('el', 'juicio'),
#  ('juicio', 'y'),
#  ('y', 'desvelábase'),
#  ('desvelábase', 'por'),
#  ('por', 'entenderlas'),
#  ('entenderlas', 'y'),
#  ('y', 'desentrañarles'),
#  ('desentrañarles', 'el'),
#  ('el', 'sentido'),
#  ('sentido', 'que'),
#  ('que', 'no'),
#  ('no', 'se'),
#  ('se', 'lo'),
#  ('lo', 'sacara'),
#  ('sacara', 'ni'),
#  ('ni', 'las'),
#  ('las', 'entendiera'),
#  ('entendiera', 'el'),
#  ('el', 'mesmo'),
#  ('mesmo', 'aristóteles'),
#  ('aristóteles', 'si'),
#  ('si', 'resucitara'),
#  ('resucitara', 'para'),
#  ('para', 'sólo'),
#  ('sólo', 'ello'),
#  ('ello', 'no'),
#  ('no', 'estaba'),
#  ('estaba', 'muy'),
#  ('muy', 'bien'),
#  ('bien', 'con'),
#  ('con', 'las'),
#  ('las', 'heridas'),
#  ('heridas', 'que'),
#  ('que', 'don'),
#  ('don', 'belianís'),
#  ('belianís', 'daba'),
#  ('daba', 'y'),
#  ('y', 'recebía'),
#  ('recebía', 'porque'),
#  ('porque', 'se'),
#  ('se', 'imaginaba'),
#  ('imaginaba', 'que'),
#  ('que', 'por'),
#  ('por', 'grandes'),
#  ('grandes', 'maestros'),
#  ('maestros', 'que'),
#  ('que', 'le'),
#  ('le', 'hubiesen'),
#  ('hubiesen', 'curado'),
#  ('curado', 'no'),
#  ('no', 'dejaría'),
#  ('dejaría', 'de'),
#  ('de', 'tener'),
#  ('tener', 'el'),
#  ('el', 'rostro'),
#  ('rostro', 'y'),
#  ('y', 'todo'),
#  ('todo', 'el'),
#  ('el', 'cuerpo'),
#  ('cuerpo', 'lleno'),
#  ('lleno', 'de'),
#  ('de', 'cicatrices'),
#  ('cicatrices', 'y'),
#  ('y', 'señales'),
#  ('señales', 'pero'),
#  ('pero', 'con'),
#  ('con', 'todo'),
#  ('todo', 'alababa'),
#  ('alababa', 'en'),
#  ('en', 'su'),
#  ('su', 'autor'),
#  ('autor', 'aquel'),
#  ('aquel', 'acabar'),
#  ('acabar', 'su'),
#  ('su', 'libro'),
#  ('libro', 'con'),
#  ('con', 'la'),
#  ('la', 'promesa'),
#  ('promesa', 'de'),
#  ('de', 'aquella'),
#  ('aquella', 'inacabable'),
#  ('inacabable', 'aventura'),
#  ('aventura', 'y'),
#  ('y', 'muchas'),
#  ('muchas', 'veces'),
#  ('veces', 'le'),
#  ('le', 'vino'),
#  ('vino', 'deseo'),
#  ('deseo', 'de'),
#  ('de', 'tomar'),
#  ('tomar', 'la'),
#  ('la', 'pluma'),
#  ('pluma', 'y'),
#  ('y', 'dalle'),
#  ('dalle', 'fin'),
#  ('fin', 'al'),
#  ('al', 'pie'),
#  ('pie', 'de'),
#  ('de', 'la'),
#  ('la', 'letra'),
#  ('letra', 'como'),
#  ('como', 'allí'),
#  ('allí', 'se'),
#  ('se', 'promete'),
#  ('promete', 'y'),
#  ('y', 'sin'),
#  ('sin', 'duda'),
#  ('duda', 'alguna'),
#  ('alguna', 'lo'),
#  ('lo', 'hiciera'),
#  ('hiciera', 'y'),
#  ('y', 'aun'),
#  ('aun', 'saliera'),
#  ('saliera', 'con'),
#  ('con', 'ello'),
#  ('ello', 'si'),
#  ('si', 'otros'),
#  ('otros', 'mayores'),
#  ('mayores', 'y'),
#  ('y', 'continuos'),
#  ('continuos', 'pensamientos'),
#  ('pensamientos', 'no'),
#  ('no', 'se'),
#  ('se', 'lo'),
#  ('lo', 'estorbaran'),
#  ('estorbaran', 'tuvo'),
#  ('tuvo', 'muchas'),
#  ('muchas', 'veces'),
#  ('veces', 'competencia'),
#  ('competencia', 'con'),
#  ('con', 'el'),
#  ('el', 'cura'),
#  ('cura', 'de'),
#  ('de', 'su'),
#  ('su', 'lugar'),
#  ('lugar', 'que'),
#  ('que', 'era'),
#  ('era', 'hombre'),
#  ('hombre', 'docto'),
#  ('docto', 'graduado'),
#  ('graduado', 'en'),
#  ('en', 'sigüenza'),
#  ('sigüenza', 'sobre'),
#  ('sobre', 'cuál'),
#  ('cuál', 'había'),
#  ('había', 'sido'),
#  ('sido', 'mejor'),
#  ('mejor', 'caballero'),
#  ('caballero', 'palmerín'),
#  ('palmerín', 'de'),
#  ('de', 'ingalaterra'),
#  ('ingalaterra', 'o'),
#  ('o', 'amadís'),
#  ('amadís', 'de'),
#  ('de', 'gaula'),
#  ('gaula', 'mas'),
#  ('mas', 'maese'),
#  ('maese', 'nicolás'),
#  ('nicolás', 'barbero'),
#  ('barbero', 'del'),
#  ('del', 'mesmo'),
#  ('mesmo', 'pueblo'),
#  ('pueblo', 'decía'),
#  ('decía', 'que'),
#  ('que', 'ninguno'),
#  ('ninguno', 'llegaba'),
#  ('llegaba', 'al'),
#  ('al', 'caballero'),
#  ('caballero', 'del'),
#  ('del', 'febo'),
#  ('febo', 'y'),
#  ('y', 'que'),
#  ('que', 'si'),
#  ('si', 'alguno'),
#  ('alguno', 'se'),
#  ('se', 'le'),
#  ('le', 'podía'),
#  ('podía', 'comparar'),
#  ('comparar', 'era'),
#  ('era', 'don'),
#  ('don', 'galaor'),
#  ('galaor', 'hermano'),
#  ('hermano', 'de'),
#  ('de', 'amadís'),
#  ('amadís', 'de'),
#  ('de', 'gaula'),
#  ('gaula', 'porque'),
#  ('porque', 'tenía'),
#  ('tenía', 'muy'),
#  ('muy', 'acomodada'),
#  ('acomodada', 'condición'),
#  ('condición', 'para'),
#  ('para', 'todo'),
#  ('todo', 'que'),
#  ('que', 'no'),
#  ('no', 'era'),
#  ('era', 'caballero'),
#  ('caballero', 'melindroso'),
#  ('melindroso', 'ni'),
#  ('ni', 'tan'),
#  ('tan', 'llorón'),
#  ('llorón', 'como'),
#  ('como', 'su'),
#  ('su', 'hermano'),
#  ('hermano', 'y'),
#  ('y', 'que'),
#  ('que', 'en'),
#  ('en', 'lo'),
#  ('lo', 'de'),
#  ('de', 'la'),
#  ('la', 'valentía'),
#  ('valentía', 'no'),
#  ('no', 'le'),
#  ('le', 'iba'),
#  ('iba', 'en'),
#  ('en', 'zaga'),
#  ('zaga', 'en'),
#  ('en', 'resolución'),
#  ('resolución', 'él'),
#  ('él', 'se'),
#  ('se', 'enfrascó'),
#  ('enfrascó', 'tanto'),
#  ('tanto', 'en'),
#  ('en', 'su'),
#  ('su', 'letura'),
#  ('letura', 'que'),
#  ('que', 'se'),
#  ('se', 'le'),
#  ('le', 'pasaban'),
#  ('pasaban', 'las'),
#  ('las', 'noches'),
#  ('noches', 'leyendo'),
#  ('leyendo', 'de'),
#  ('de', 'claro'),
#  ('claro', 'en'),
#  ('en', 'claro'),
#  ('claro', 'y'),
#  ('y', 'los'),
#  ('los', 'días'),
#  ('días', 'de'),
#  ('de', 'turbio'),
#  ('turbio', 'en'),
#  ('en', 'turbio'),
#  ('turbio', 'y'),
#  ('y', 'así'),
#  ('así', 'del'),
#  ('del', 'poco'),
#  ('poco', 'dormir'),
#  ('dormir', 'y'),
#  ('y', 'del'),
#  ('del', 'mucho'),
#  ('mucho', 'leer'),
#  ('leer', 'se'),
#  ('se', 'le'),
#  ('le', 'secó'),
#  ('secó', 'el'),
#  ('el', 'celebro'),
#  ('celebro', 'de'),
#  ('de', 'manera'),
#  ('manera', 'que'),
#  ('que', 'vino'),
#  ('vino', 'a'),
#  ('a', 'perder'),
#  ('perder', 'el'),
#  ('el', 'juicio'),
#  ('juicio', 'llenósele'),
#  ('llenósele', 'la'),
#  ('la', 'fantasía'),
#  ('fantasía', 'de'),
#  ('de', 'todo'),
#  ('todo', 'aquello'),
#  ('aquello', 'que'),
#  ('que', 'leía'),
#  ('leía', 'en'),
#  ('en', 'los'),
#  ('los', 'libros'),
#  ('libros', 'así'),
#  ('así', 'de'),
#  ('de', 'encantamentos'),
#  ('encantamentos', 'como'),
#  ('como', 'de'),
#  ('de', 'pendencias'),
#  ('pendencias', 'batallas'),
#  ('batallas', 'desafíos'),
#  ('desafíos', 'heridas'),
#  ('heridas', 'requiebros'),
#  ('requiebros', 'amores'),
#  ('amores', 'tormentas'),
#  ('tormentas', 'y'),
#  ('y', 'disparates'),
#  ('disparates', 'imposibles'),
#  ('imposibles', 'y'),
#  ('y', 'asentósele'),
#  ('asentósele', 'de'),
#  ('de', 'tal'),
#  ('tal', 'modo'),
#  ('modo', 'en'),
#  ('en', 'la'),
#  ('la', 'imaginación'),
#  ('imaginación', 'que'),
#  ('que', 'era'),
#  ('era', 'verdad'),
#  ('verdad', 'toda'),
#  ('toda', 'aquella'),
#  ('aquella', 'máquina'),
#  ('máquina', 'de'),
#  ('de', 'aquellas'),
#  ('aquellas', 'sonadas'),
#  ('sonadas', 'soñadas'),
#  ('soñadas', 'invenciones'),
#  ('invenciones', 'que'),
#  ('que', 'leía'),
#  ('leía', 'que'),
#  ('que', 'para'),
#  ('para', 'él'),
#  ('él', 'no'),
#  ('no', 'había'),
#  ('había', 'otra'),
#  ('otra', 'historia'),
#  ('historia', 'más'),
#  ('más', 'cierta'),
#  ('cierta', 'en'),
#  ('en', 'el'),
#  ('el', 'mundo'),
#  ('mundo', 'decía'),
#  ('decía', 'él'),
#  ('él', 'que'),
#  ('que', 'el'),
#  ('el', 'cid'),
#  ('cid', 'ruy'),
#  ('ruy', 'díaz'),
#  ('díaz', 'había'),
#  ('había', 'sido'),
#  ('sido', 'muy'),
#  ('muy', 'buen'),
#  ('buen', 'caballero'),
#  ('caballero', 'pero'),
#  ('pero', 'que'),
#  ('que', 'no'),
#  ('no', 'tenía'),
#  ('tenía', 'que'),
#  ('que', 'ver'),
#  ('ver', 'con'),
#  ('con', 'el'),
#  ('el', 'caballero'),
#  ('caballero', 'de'),
#  ('de', 'la'),
#  ('la', 'ardiente'),
#  ('ardiente', 'espada'),
#  ('espada', 'que'),
#  ('que', 'de'),
#  ('de', 'sólo'),
#  ('sólo', 'un'),
#  ('un', 'revés'),
#  ('revés', 'había'),
#  ('había', 'partido'),
#  ('partido', 'por'),
#  ('por', 'medio'),
#  ('medio', 'dos'),
#  ('dos', 'fieros'),
#  ('fieros', 'y'),
#  ('y', 'descomunales'),
#  ('descomunales', 'gigantes'),
#  ('gigantes', 'mejor'),
#  ('mejor', 'estaba'),
#  ('estaba', 'con'),
#  ('con', 'bernardo'),
#  ('bernardo', 'del'),
#  ('del', 'carpio'),
#  ('carpio', 'porque'),
#  ('porque', 'en'),
#  ('en', 'roncesvalles'),
#  ('roncesvalles', 'había'),
#  ('había', 'muerto'),
#  ('muerto', 'a'),
#  ('a', 'roldán'),
#  ('roldán', 'el'),
#  ('el', 'encantado'),
#  ('encantado', 'valiéndose'),
#  ('valiéndose', 'de'),
#  ('de', 'la'),
#  ('la', 'industria'),
#  ('industria', 'de'),
#  ('de', 'hércules'),
#  ('hércules', 'cuando'),
#  ('cuando', 'ahogó'),
#  ('ahogó', 'a'),
#  ('a', 'anteo'),
#  ('anteo', 'el'),
#  ('el', 'hijo'),
#  ('hijo', 'de'),
#  ('de', 'la'),
#  ('la', 'tierra'),
#  ('tierra', 'entre'),
#  ('entre', 'los'),
#  ('los', 'brazos'),
#  ('brazos', 'decía'),
#  ('decía', 'mucho'),
#  ('mucho', 'bien'),
#  ('bien', 'del'),
#  ('del', 'gigante'),
#  ('gigante', 'morgante'),
#  ('morgante', 'porque'),
#  ('porque', 'con'),
#  ('con', 'ser'),
#  ('ser', 'de'),
#  ('de', 'aquella'),
#  ('aquella', 'generación'),
#  ('generación', 'gigantea'),
#  ('gigantea', 'que'),
#  ('que', 'todos'),
#  ('todos', 'son'),
#  ('son', 'soberbios'),
#  ('soberbios', 'y'),
#  ('y', 'descomedidos'),
#  ('descomedidos', 'él'),
#  ('él', 'solo'),
#  ('solo', 'era'),
#  ('era', 'afable'),
#  ('afable', 'y'),
#  ('y', 'bien'),
#  ('bien', 'criado'),
#  ('criado', 'pero'),
#  ('pero', 'sobre'),
#  ('sobre', 'todos'),
#  ('todos', 'estaba'),
#  ('estaba', 'bien'),
#  ('bien', 'con'),
#  ('con', 'reinaldos'),
#  ('reinaldos', 'de'),
#  ('de', 'montalbán'),
#  ('montalbán', 'y'),
#  ('y', 'más'),
#  ('más', 'cuando'),
#  ('cuando', 'le'),
#  ('le', 'veía'),
#  ('veía', 'salir'),
#  ('salir', 'de'),
#  ('de', 'su'),
#  ('su', 'castillo'),
#  ('castillo', 'y'),
#  ('y', 'robar'),
#  ('robar', 'cuantos'),
#  ('cuantos', 'topaba'),
#  ('topaba', 'y'),
#  ('y', 'cuando'),
#  ('cuando', 'en'),
#  ('en', 'allende'),
#  ('allende', 'robó'),
#  ('robó', 'aquel'),
#  ('aquel', 'ídolo'),
#  ('ídolo', 'de'),
#  ('de', 'mahoma'),
#  ('mahoma', 'que'),
#  ('que', 'era'),
#  ('era', 'todo'),
#  ('todo', 'de'),
#  ('de', 'oro'),
#  ('oro', 'según'),
#  ('según', 'dice'),
#  ('dice', 'su'),
#  ('su', 'historia'),
#  ('historia', 'diera'),
#  ('diera', 'él'),
#  ('él', 'por'),
#  ('por', 'dar'),
#  ('dar', 'una'),
#  ('una', 'mano'),
#  ('mano', 'de'),
#  ('de', 'coces'),
#  ('coces', 'al'),
#  ('al', 'traidor'),
#  ('traidor', 'de'),
#  ('de', 'galalón'),
#  ('galalón', 'al'),
#  ('al', 'ama'),
#  ('ama', 'que'),
#  ('que', 'tenía'),
#  ('tenía', 'y'),
#  ('y', 'aun'),
#  ('aun', 'a'),
#  ('a', 'su'),
#  ('su', 'sobrina'),
#  ('sobrina', 'de'),
#  ('de', 'añadidura'),
#  ('añadidura', 'en'),
#  ('en', 'efeto'),
#  ('efeto', 'rematado'),
#  ('rematado', 'ya'),
#  ('ya', 'su'),
#  ('su', 'juicio'),
#  ('juicio', 'vino'),
#  ('vino', 'a'),
#  ('a', 'dar'),
#  ('dar', 'en'),
#  ('en', 'el'),
#  ('el', 'más'),
#  ('más', 'estraño'),
#  ('estraño', 'pensamiento'),
#  ('pensamiento', 'que'),
#  ('que', 'jamás'),
#  ('jamás', 'dio'),
#  ('dio', 'loco'),
#  ('loco', 'en'),
#  ('en', 'el'),
#  ('el', 'mundo'),
#  ('mundo', 'y'),
#  ('y', 'fue'),
#  ('fue', 'que'),
#  ('que', 'le'),
#  ('le', 'pareció'),
#  ('pareció', 'convenible'),
#  ('convenible', 'y'),
#  ('y', 'necesario'),
#  ('necesario', 'así'),
#  ('así', 'para'),
#  ('para', 'el'),
#  ('el', 'aumento'),
#  ('aumento', 'de'),
#  ('de', 'su'),
#  ('su', 'honra'),
#  ('honra', 'como'),
#  ('como', 'para'),
#  ('para', 'el'),
#  ('el', 'servicio'),
#  ('servicio', 'de'),
#  ('de', 'su'),
#  ('su', 'república'),
#  ('república', 'hacerse'),
#  ('hacerse', 'caballero'),
#  ('caballero', 'andante'),
#  ('andante', 'y'),
#  ('y', 'irse'),
#  ('irse', 'por'),
#  ('por', 'todo'),
#  ('todo', 'el'),
#  ('el', 'mundo'),
#  ('mundo', 'con'),
#  ('con', 'sus'),
#  ('sus', 'armas'),
#  ('armas', 'y'),
#  ('y', 'caballo'),
#  ('caballo', 'a'),
#  ('a', 'buscar'),
#  ('buscar', 'las'),
#  ('las', 'aventuras'),
#  ('aventuras', 'y'),
#  ('y', 'a'),
#  ('a', 'ejercitarse'),
#  ('ejercitarse', 'en'),
#  ('en', 'todo'),
#  ('todo', 'aquello'),
#  ('aquello', 'que'),
#  ('que', 'él'),
#  ('él', 'había'),
#  ('había', 'leído'),
#  ('leído', 'que'),
#  ('que', 'los'),
#  ('los', 'caballeros'),
#  ...]

# %%
# Obtener la frecuencia de cada bigrama.
frequency = {}
for bigram in bigrams:
    first_word, second_word = bigram
    if first_word in frequency:
        frequency[first_word][second_word] = frequency[first_word].get(second_word, 0) + 1
    else:
        frequency[first_word] = {second_word: 1}

# Crear el DataFrame.
data = []
for first_word in frequency:
    for second_word in frequency[first_word]:
        freq = frequency[first_word][second_word]
        data.append([first_word, second_word, freq])

df_probabilidad = pd.DataFrame(data, columns=['Primera palabra', 'Segunda palabra', 'Frecuencia'])
df_probabilidad
# Out:
#        Primera palabra Segunda palabra  Frecuencia
# 0              primera           parte          13
# 1              primera          salida           1
# 2              primera         salidad           1
# 3              primera        aventura           4
# 4              primera         afrenta           1
# ...                ...             ...         ...
# 152386       resfriado         ingenio           1
# 152387      advertirás              si           1
# 152388           fuesa           donde           1
# 152389     aconsejando            bien           1
# 152390     enteramente            como           1
#
# [152391 rows x 3 columns]

# %%
bigrams.count(('de', 'cuyo'))
# Out:
# 13

# %%
df_probabilidad['Probabilidad'] = df_probabilidad['Frecuencia']/df_probabilidad.groupby('Primera palabra')['Frecuencia'].transform('sum')*100

# %%
df_probabilidad
# Out:
#        Primera palabra Segunda palabra  Frecuencia  Probabilidad
# 0              primera           parte          13     14.130435
# 1              primera          salida           1      1.086957
# 2              primera         salidad           1      1.086957
# 3              primera        aventura           4      4.347826
# 4              primera         afrenta           1      1.086957
# ...                ...             ...         ...           ...
# 152386       resfriado         ingenio           1    100.000000
# 152387      advertirás              si           1    100.000000
# 152388           fuesa           donde           1    100.000000
# 152389     aconsejando            bien           1    100.000000
# 152390     enteramente            como           1    100.000000
#
# [152391 rows x 4 columns]

# %%
import heapq

def build_huffman_tree(df):
    frequencies = df.set_index(['Primera palabra', 'Segunda palabra'])['Probabilidad'].to_dict()
    heap = [[weight, [symbol, '']] for symbol, weight in frequencies.items()]
    heapq.heapify(heap)
    while len(heap) > 1:
        lo = heapq.heappop(heap)
        hi = heapq.heappop(heap)
        for pair in lo[1:]:
            pair[1] = '0' + pair[1]
        for pair in hi[1:]:
            pair[1] = '1' + pair[1]
        heapq.heappush(heap, [lo[0] + hi[0]] + lo[1:] + hi[1:])
    return heap[0]

df_word_primera = df_probabilidad[df_probabilidad['Primera palabra'] == 'primera']

huffman_tree = build_huffman_tree(df_word_primera)
print(huffman_tree)
# Out:
# [100.0, [('primera', 'nos'), '000000'], [('primera', 'opinión'), '000001'], [('primera', 'persona'), '000010'], [('primera', 'por'), '000011'], [('primera', 'pregunta'), '000100'], [('primera', 'salida'), '000101'], [('primera', 'salidad'), '000110'], [('primera', 'satisfación'), '000111'], [('primera', 'que'), '001'], [('primera', 'y'), '010'], [('primera', 'vez'), '0110'], [('primera', 'se'), '011100'], [('primera', 'tierra'), '011101'], [('primera', 'veían'), '011110'], [('primera', 'a'), '0111110'], [('primera', 'afrenta'), '0111111'], [('primera', 'parte'), '100'], [('primera', 'ocasión'), '1010'], [('primera', 'anda'), '1011000'], [('primera', 'belleza'), '1011001'], [('primera', 'cena'), '1011010'], [('primera', 'clavásedes'), '1011011'], [('primera', 'aventura'), '10111'], [('primera', 'cuando'), '110000'], [('primera', 'de'), '110001'], [('primera', 'declaración'), '1100100'], [('primera', 'desenvoltura'), '1100101'], [('primera', 'dádiva'), '1100110'], [('primera', 'ella'), '1100111'], [('primera', 'el'), '110100'], [('primera', 'encina'), '1101010'], [('primera', 'es'), '1101011'], [('primera', 'especie'), '1101100'], [('primera', 'estuvo'), '1101101'], [('primera', 'facción'), '1101110'], [('primera', 'figura'), '1101111'], [('primera', 'forma'), '1110000'], [('primera', 'haber'), '1110001'], [('primera', 'historia'), '1110010'], [('primera', 'imagen'), '1110011'], [('primera', 'impresión'), '1110100'], [('primera', 'jaula'), '1110101'], [('primera', 'intención'), '111011'], [('primera', 'jornada'), '1111000'], [('primera', 'la'), '1111001'], [('primera', 'le'), '111101'], [('primera', 'letra'), '1111100'], [('primera', 'lisura'), '1111101'], [('primera', 'los'), '1111110'], [('primera', 'madre'), '1111111']]

# %%
df_probabilidad[df_probabilidad['Primera palabra'] == 'parte']
# Out:
#     Primera palabra Segunda palabra  Frecuencia  Probabilidad
# 50            parte             del          23      6.442577
# 51            parte               a          20      5.602241
# 52            parte              de          72     20.168067
# 53            parte             con           8      2.240896
# 54            parte              no           6      1.680672
# ..              ...             ...         ...           ...
# 151           parte       docientos           1      0.280112
# 152           parte             los           1      0.280112
# 153           parte          puedes           1      0.280112
# 154           parte        corregir           1      0.280112
# 155           parte             fue           1      0.280112
#
# [106 rows x 4 columns]

# %%
df_word_parte = df_probabilidad[df_probabilidad['Primera palabra'] == 'parte']

huffman_tree = build_huffman_tree(df_word_parte)
print(huffman_tree)
# Out:
# [100.0, [('parte', 'segura'), '00000000'], [('parte', 'si'), '00000001'], [('parte', 'siguiendo'), '00000010'], [('parte', 'son'), '00000011'], [('parte', 'sin'), '0000010'], [('parte', 'sino'), '0000011'], [('parte', 'sonaba'), '00001000'], [('parte', 'su'), '00001001'], [('parte', 'suele'), '00001010'], [('parte', 'sueltos'), '00001011'], [('parte', 'suntuosos'), '00001100'], [('parte', 'suya'), '00001101'], [('parte', 'sí'), '00001110'], [('parte', 'te'), '00001111'], [('parte', 'tengo'), '00010000'], [('parte', 'tenía'), '00010001'], [('parte', 'teníades'), '00010010'], [('parte', 'tercera'), '00010011'], [('parte', 'tienen'), '00010100'], [('parte', 'toca'), '00010101'], [('parte', 'todo'), '00010110'], [('parte', 'todos'), '00010111'], [('parte', 'tranzados'), '00011000'], [('parte', 'tú'), '00011001'], [('parte', 'un'), '00011010'], [('parte', 'vengamos'), '00011011'], [('parte', 'venguéis'), '00011100'], [('parte', 'verisímiles'), '00011101'], [('parte', 'vuestra'), '00011110'], [('parte', 'ya'), '00011111'], [('parte', 'y'), '0010'], [('parte', 'desta'), '00110'], [('parte', 'por'), '001110'], [('parte', 'dellas'), '0011110'], [('parte', 'estaba'), '0011111'], [('parte', 'de'), '01'], [('parte', 'a'), '1000'], [('parte', 'del'), '1001'], [('parte', 'me'), '101000'], [('parte', 'ni'), '1010010'], [('parte', 'se'), '1010011'], [('parte', 'no'), '101010'], [('parte', 'tan'), '1010110'], [('parte', 'veo'), '1010111'], [('parte', 'que'), '1011'], [('parte', 'para'), '11000'], [('parte', 'en'), '110010'], [('parte', 'la'), '110011'], [('parte', 'al'), '110100000'], [('parte', 'alega'), '110100001'], [('parte', 'alguna'), '11010001'], [('parte', 'ante'), '110100100'], [('parte', 'aunque'), '110100101'], [('parte', 'ayudaría'), '110100110'], [('parte', 'buscándole'), '110100111'], [('parte', 'carecen'), '110101000'], [('parte', 'cargan'), '110101001'], [('parte', 'comenzaría'), '110101010'], [('parte', 'considero'), '110101011'], [('parte', 'como'), '1101011'], [('parte', 'con'), '110110'], [('parte', 'contraria'), '11011100'], [('parte', 'corregir'), '110111010'], [('parte', 'creo'), '110111011'], [('parte', 'cuatro'), '110111100'], [('parte', 'della'), '110111101'], [('parte', 'diciendo'), '110111110'], [('parte', 'diese'), '110111111'], [('parte', 'digo'), '111000000'], [('parte', 'docientos'), '111000001'], [('parte', 'dos'), '111000010'], [('parte', 'désta'), '111000011'], [('parte', 'el'), '11100010'], [('parte', 'entraba'), '111000110'], [('parte', 'es'), '111000111'], [('parte', 'estamos'), '111001000'], [('parte', 'estas'), '111001001'], [('parte', 'finalmente'), '111001010'], [('parte', 'fue'), '111001011'], [('parte', 'ha'), '111001100'], [('parte', 'hacer'), '111001101'], [('parte', 'hallamos'), '111001110'], [('parte', 'han'), '111001111'], [('parte', 'donde'), '11101'], [('parte', 'has'), '111100000'], [('parte', 'las'), '111100001'], [('parte', 'he'), '11110001'], [('parte', 'le'), '1111001'], [('parte', 'los'), '111101000'], [('parte', 'mas'), '111101001'], [('parte', 'luego'), '11110101'], [('parte', 'mentira'), '111101100'], [('parte', 'mostraba'), '111101101'], [('parte', 'más'), '11110111'], [('parte', 'nos'), '111110000'], [('parte', 'nuevas'), '111110001'], [('parte', 'o'), '11111001'], [('parte', 'os'), '1111101'], [('parte', 'par'), '111111000'], [('parte', 'pero'), '111111001'], [('parte', 'pidiese'), '111111010'], [('parte', 'procurando'), '111111011'], [('parte', 'puedes'), '111111100'], [('parte', 'pues'), '111111101'], [('parte', 'quiero'), '111111110'], [('parte', 'segunda'), '111111111']]

# %%
df_temp = pd.DataFrame(columns=['Primera palabra', 'Segunda palabra', 'Bits'])
groups = df_probabilidad.groupby('Primera palabra')

for group_name, group_df in groups:
    huffman_tree = build_huffman_tree(group_df)
    temp_rows = []
    for pair in huffman_tree[1:]:
        first_word, second_word = pair[0]
        bits = pair[1]
        temp_rows.append({'Primera palabra': first_word, 'Segunda palabra': second_word, 'Bits': bits})
    
    df_temp = pd.concat([df_temp, pd.DataFrame(temp_rows)], ignore_index=True)

df_probabilidad = df_probabilidad.merge(df_temp, on=['Primera palabra', 'Segunda palabra'], how='outer')

# %%
df_probabilidad[150:160]
# Out:
#     Primera palabra Segunda palabra  Frecuencia  Probabilidad         Bits
# 150           parte         entraba           1      0.280112    111000110
# 151           parte       docientos           1      0.280112    111000001
# 152           parte             los           1      0.280112    111101000
# 153           parte          puedes           1      0.280112    111111100
# 154           parte        corregir           1      0.280112    110111010
# 155           parte             fue           1      0.280112    111001011
# 156             del       ingenioso          10      0.407830     10101101
# 157             del          famoso          12      0.489396     11010001
# 158             del             año           3      0.122349   1100010001
# 159             del    merecimiento           1      0.040783  01010011110
